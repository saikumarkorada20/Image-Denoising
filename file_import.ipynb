  https://newcodalab.lri.fr/prod-private/dataset_data_file/None/0ca24/SIDD_Medium_Srgb_Parts.z10?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=fe5c4e6a009bc8cd1ccf521e8f1dcbcfff647b93bcece8480e69e32d80e0893b&X-Amz-Date=20200428T124554Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.11
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1073741824 (1.0G) [application/octet-stream]
# Saving to: ‘SIDD_Medium_Srgb_Parts.z10’
#
# SIDD_Medium_Srgb_Pa 100%[===================>]   1.00G  13.0MB/s    in 46s
#
# 2020-04-28 14:20:10 (22.5 MB/s) - ‘SIDD_Medium_Srgb_Parts.z10’ saved [1073741824/1073741824]

# %%
# !wget --header="Host: newcodalab.lri.fr" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://competitions.codalab.org/competitions/22231" "https://newcodalab.lri.fr/prod-private/dataset_data_file/None/f3c20/SIDD_Medium_Srgb_Parts.z11?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=85db83f0be4a56dbcb3076eb834ee9173813b0e4f77a4f8dd54dfd92f03cc7a5&X-Amz-Date=20200428T124612Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request" -c -O 'SIDD_Medium_Srgb_Parts.z11'
# Out:
# --2020-04-28 14:20:10--  https://newcodalab.lri.fr/prod-private/dataset_data_file/None/f3c20/SIDD_Medium_Srgb_Parts.z11?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=85db83f0be4a56dbcb3076eb834ee9173813b0e4f77a4f8dd54dfd92f03cc7a5&X-Amz-Date=20200428T124612Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.11
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1073741824 (1.0G) [application/octet-stream]
# Saving to: ‘SIDD_Medium_Srgb_Parts.z11’
#
# SIDD_Medium_Srgb_Pa 100%[===================>]   1.00G  6.54MB/s    in 1m 46s
#
# 2020-04-28 14:21:57 (9.67 MB/s) - ‘SIDD_Medium_Srgb_Parts.z11’ saved [1073741824/1073741824]

# %%
# !wget --header="Host: newcodalab.lri.fr" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://competitions.codalab.org/competitions/22231" "https://newcodalab.lri.fr/prod-private/dataset_data_file/None/d7719/SIDD_Medium_Srgb_Parts.z12?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=a97c6920c26a2eeac69d2ef7a28f2d0af957b03de2537be335ac50bf6975bb1c&X-Amz-Date=20200428T124203Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request" -c -O 'SIDD_Medium_Srgb_Parts.z12'
# Out:
# --2020-04-28 14:21:57--  https://newcodalab.lri.fr/prod-private/dataset_data_file/None/d7719/SIDD_Medium_Srgb_Parts.z12?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=a97c6920c26a2eeac69d2ef7a28f2d0af957b03de2537be335ac50bf6975bb1c&X-Amz-Date=20200428T124203Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.11
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1073741824 (1.0G) [application/octet-stream]
# Saving to: ‘SIDD_Medium_Srgb_Parts.z12’
#
# SIDD_Medium_Srgb_Pa 100%[===================>]   1.00G  14.7MB/s    in 37s
#
# 2020-04-28 14:22:34 (27.4 MB/s) - ‘SIDD_Medium_Srgb_Parts.z12’ saved [1073741824/1073741824]

# %%
import os
print(os.getcwd())
for dirname, _, filenames in os.walk('/home/jupyter/Data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# '/home/jupyter'

# %%
# !zip -FF SIDD_Medium_Srgb_Parts.zip --out combined.zip
# Out:
# Fix archive (-FF) - salvage what can
#  Found end record (EOCDR) - says expect 13 splits
# Scanning for entries...
#   Found spanning marker - expected as this is split (multi-disk) archive...
#  copying: SIDD_Medium_Srgb/  (0 bytes)
#  copying: SIDD_Medium_Srgb/Data/  (0 bytes)
#  copying: SIDD_Medium_Srgb/Data/0001_001_S6_00100_00060_3200_L/  (0 bytes)
#  copying: SIDD_Medium_Srgb/Data/0001_001_S6_00100_00060_3200_L/0001_GT_SRGB_010.PNG  (12755939 bytes)
#  copying: SIDD_Medium_Srgb/Data/0001_001_S6_00100_00060_3200_L/0001_GT_SRGB_011.PNG  (12805523 bytes)
#  copying: SIDD_Medium_Srgb/Data/0001_001_S6_00100_00060_3200_L/0001_NOISY_SRGB_010.PNG  (27512626 bytes)
#  copying: SIDD_Medium_Srgb/Data/0001_001_S6_00100_00060_3200_L/0001_NOISY_SRGB_011.PNG  (27510518 bytes)
#  copying: SIDD_Medium_Srgb/Data/0002_001_S6_00100_00020_3200_N/  (0 bytes)
#  copying: SIDD_Medium_Srgb/Data/0002_001_S6_00100_00020_3200_N/0002_GT_SRGB_010.PNG  (13358955 bytes)
# ...

# %%
import zipfile
with zipfile.ZipFile("/home/jupyter/combined.zip", 'r') as zip_ref:
    zip_ref.extractall('/home/jupyter/Data/Output Data')

# %%
# !wget --header="Host: newcodalab.lri.fr" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://competitions.codalab.org/competitions/22231" "https://newcodalab.lri.fr/prod-private/dataset_data_file/None/fec1d/siddplus_valid_noisy_srgb.mat?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=766ac9876d1c9de6b83253525ad8bbec99c6d8afc7f58fe4b474aa34ffd8de42&X-Amz-Date=20200428T155006Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request" -c -O 'siddplus_valid_noisy_srgb.mat'
# Out:
# --2020-04-28 16:14:48--  https://newcodalab.lri.fr/prod-private/dataset_data_file/None/fec1d/siddplus_valid_noisy_srgb.mat?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=766ac9876d1c9de6b83253525ad8bbec99c6d8afc7f58fe4b474aa34ffd8de42&X-Amz-Date=20200428T155006Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.11
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 175725611 (168M) [application/octet-stream]
# Saving to: ‘siddplus_valid_noisy_srgb.mat’
#
# siddplus_valid_nois 100%[===================>] 167.58M  29.7MB/s    in 6.2s
#
# 2020-04-28 16:14:55 (26.9 MB/s) - ‘siddplus_valid_noisy_srgb.mat’ saved [175725611/175725611]

# %%
# !wget --header="Host: newcodalab.lri.fr" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://competitions.codalab.org/competitions/22231" "https://newcodalab.lri.fr/prod-private/dataset_data_file/None/6b83d/siddplus_test_noisy_srgb.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=dce184171685b08d2c6befc767e3b0ec6478dfa3fe3b98d9b41bd4b5dc3b372c&X-Amz-Date=20200428T162054Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request" -c -O 'siddplus_test_noisy_srgb.zip'
# Out:
# --2020-04-28 16:21:20--  https://newcodalab.lri.fr/prod-private/dataset_data_file/None/6b83d/siddplus_test_noisy_srgb.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=dce184171685b08d2c6befc767e3b0ec6478dfa3fe3b98d9b41bd4b5dc3b372c&X-Amz-Date=20200428T162054Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.11
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182556993 (174M) [application/zip]
# Saving to: ‘siddplus_test_noisy_srgb.zip’
#
# siddplus_test_noisy 100%[===================>] 174.10M  11.5MB/s    in 28s
#
# 2020-04-28 16:21:48 (6.25 MB/s) - ‘siddplus_test_noisy_srgb.zip’ saved [182556993/182556993]

# %%
# !wget --header="Host: newcodalab.lri.fr" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://competitions.codalab.org/competitions/22231" "https://newcodalab.lri.fr/prod-private/dataset_data_file/None/39fa3/siddplus_valid_gt_srgb.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=83c50b2a02cdf80e5d33f7503d9ba47579fa6529c93f7d05514875f371ea22c2&X-Amz-Date=20200428T162501Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request" -c -O 'siddplus_valid_gt_srgb.zip'
# Out:
# --2020-04-28 16:25:30--  https://newcodalab.lri.fr/prod-private/dataset_data_file/None/39fa3/siddplus_valid_gt_srgb.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-SignedHeaders=host&X-Amz-Signature=83c50b2a02cdf80e5d33f7503d9ba47579fa6529c93f7d05514875f371ea22c2&X-Amz-Date=20200428T162501Z&X-Amz-Credential=AZIAIOSAODNN7EX123LE%2F20200428%2Fnewcodalab%2Fs3%2Faws4_request
# Resolving newcodalab.lri.fr (newcodalab.lri.fr)... 129.175.15.11
# Connecting to newcodalab.lri.fr (newcodalab.lri.fr)|129.175.15.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156569879 (149M) [application/zip]
# Saving to: ‘siddplus_valid_gt_srgb.zip’
#
# siddplus_valid_gt_s 100%[===================>] 149.32M  21.9MB/s    in 6.5s
#
# 2020-04-28 16:25:37 (22.8 MB/s) - ‘siddplus_valid_gt_srgb.zip’ saved [156569879/156569879]

# %%
# !unzip siddplus_valid_gt_srgb.zip
# Out:
# Archive:  siddplus_valid_gt_srgb.zip
#    creating: siddplus_valid_gt_srgb/
#  extracting: siddplus_valid_gt_srgb/metadata
#   inflating: siddplus_valid_gt_srgb/siddplus_valid_gt_srgb.mat
